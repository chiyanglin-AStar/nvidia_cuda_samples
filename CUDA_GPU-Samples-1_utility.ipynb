# %% [markdown]
# <a href="https://githubtocolab.com/chiyanglin-AStar/nvidia_cuda_samples/edit/master/CUDA_GPU-Samples-1_utility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %% [markdown]
# # Install Nvidia & other dependencies
#
# in this version , remove colab have built-in package install steps

# %% [markdown]
# # Show our GPU

# %%
! nvidia-smi
# Out:
# Mon Oct 31 20:54:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # C Compiler

# %%
# !gcc -v
# Out:
# Using built-in specs.
# COLLECT_GCC=gcc
# COLLECT_LTO_WRAPPER=/usr/lib/gcc/x86_64-linux-gnu/7/lto-wrapper
# OFFLOAD_TARGET_NAMES=nvptx-none
# OFFLOAD_TARGET_DEFAULT=1
# Target: x86_64-linux-gnu
# ...

# %% [markdown]
# # Install CUDA

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !apt-get update
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# ...

# %% [markdown]
# # nvcc show version , next three cells didn't run

# %%
# !apt-get install cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cuda is already the newest version (11.8.0-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
# !ls
# Out:
# bandwidth_test.cu  nvidia_cuda_samples	sample_data  src

# %% [markdown]
# # Install CUDA Toolkit

# %%
# !apt-get install nvidia-cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# nvidia-cuda-toolkit is already the newest version (9.1.85-3ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
# !cmake --version
# Out:
# cmake version 3.22.6
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %% [markdown]
# # Colab have install cmake , may not re-install Cmake
#
#
#
#
# *  CMake is an open-source, cross-platform family of tools
# *  designed to build, test and package software.
# *  Used to control the software compilation process.
# *  by using simple platform and compiler independent configuration files,
# *  generate native makefiles and workspaces that can be used in the compiler environment of your choice.

# %%
# !apt-get install cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %% [markdown]
# # Upload the Repo

# %%
# !git clone https://github.com/chiyanglin-AStar/Cuda_Colab_study.git
# Out:
# Cloning into 'Cuda_Colab_study'...
# remote: Enumerating objects: 278, done.
# remote: Counting objects: 100% (278/278), done.
# remote: Compressing objects: 100% (229/229), done.
# remote: Total 278 (delta 125), reused 140 (delta 44), pack-reused 0
# Receiving objects: 100% (278/278), 3.51 MiB | 10.84 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# !ls
# Out:
# bandwidth_test.cu  Cuda_Colab_study  nvidia_cuda_samples  sample_data  src

# %%
# %cd Cuda_Colab_study
# Out:
# /content/Cuda_Colab_study

# %%
# !mkdir build
# %cd build
# Out:
# /content/Cuda_Colab_study/build

# %%
# !ls /usr/local
# Out:
# bin	 cuda-11.2  games		lib	   sbin   xgboost
# cuda	 cuda-11.8  _gcs_config_ops.so	licensing  share
# cuda-11  etc	    include		man	   src

# %%
# !ls /usr/local/cuda
# Out:
# bin		   EULA.txt  lib64	       nvvm    targets
# compute-sanitizer  extras    libnvvp	       README  tools
# doc		   gds	     nsightee_plugins  share   version.json
# DOCS		   include   nvml	       src

# %%
! export CUDA_TOOLKIT_ROOT_DIR=/usr/local/cuda-11/

# %% [markdown]
# # Cmake

# %%
# !cmake -D CUDA_TOOLKIT_ROOT_DIR=/usr/local/cuda-11 ..
# Out:
# CMake Error: The current CMakeCache.txt directory /content/Cuda_Colab_study/CMakeCache.txt is different than the directory /workspace/Cuda_Colab_study where CMakeCache.txt was created. This may result in binaries being created in the wrong place. If you are not sure, reedit the CMakeCache.txt

# %% [markdown]
# # Building NVCC (Make)

# %%
# !make
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !ls

# %% [markdown]
# # Upload images to test

# %% [markdown]
# Git nVidia cuda samples

# %%
# !git clone https://github.com/chiyanglin-AStar/nvidia_cuda_samples.git
# Out:
# Cloning into 'nvidia_cuda_samples'...
# remote: Enumerating objects: 9702, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 9702 (delta 3), reused 0 (delta 0), pack-reused 9693
# Receiving objects: 100% (9702/9702), 119.38 MiB | 17.51 MiB/s, done.
# Resolving deltas: 100% (8271/8271), done.
# Checking out files: 100% (3613/3613), done.

# %% [markdown]
# bandwidthTest - Bandwidth Test
#
# Description
# This is a simple test program to measure the memcopy bandwidth of the GPU and memcpy bandwidth across PCI-e. This test application is capable of measuring device to device copy bandwidth, host to device copy bandwidth for pageable and page-locked memory, and device to host copy bandwidth for pageable and page-locked memory.

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-r7caumrw
#   Running command git clone -q https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-r7caumrw

# %%
# %load_ext nvcc_plugin
# Out:
# created output directory at /content/Cuda_Colab_study/build/src
# Out bin /content/Cuda_Colab_study/build/result.out

# %%
# !apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tree is already the newest version (1.7.0-5).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
# !cd nvidia_cuda_samples

# %%
# !tree .
# Out:
# .
# ├── nvidia_cuda_samples
# │   ├── bin
# │   │   └── win64
# │   │       ├── Debug
# │   │       │   ├── freeglut.dll
# │   │       │   └── glew64.dll
# │   │       └── Release
# │   │           ├── freeglut.dll
# │   │           └── glew64.dll
# │   ├── CHANGELOG.md
# │   ├── Common
# │   │   ├── data
# │   │   │   ├── CT_skull_512x512_8u_Gray.raw
# │   │   │   ├── CT_skull_512x512_8u.raw
# │   │   │   ├── PCB_1280x720_8u.raw
# │   │   │   ├── PCB2_1024x683_8u.raw
# │   │   │   ├── PCB_METAL_509x335_8u.raw
# │   │   │   ├── Rocks_512x512_8u_Gray.raw
# │   │   │   ├── teapot512.pgm
# │   │   │   ├── teapot_512x512_8u_Gray.raw
# │   │   │   └── teapot_512x512_8u.raw
# │   │   ├── drvapi_error_string.h
# │   │   ├── dynlink_d3d10.h
# │   │   ├── dynlink_d3d11.h
# │   │   ├── exception.h
# │   │   ├── GL
# │   │   │   ├── freeglut_ext.h
# │   │   │   ├── freeglut.h
# │   │   │   ├── freeglut_std.h
# │   │   │   ├── glew.h
# │   │   │   ├── glext.h
# │   │   │   ├── glut.h
# ...

# %% [markdown]
# check the path of samples directory

# %%
# !cd ./nvidia_cuda_samples/Samples/0_Introduction/asyncAPI

# %%
# !ls
# Out:
# nvidia_cuda_samples  src

# %%
# !ls ./nvidia_cuda_samples/Samples/0_Introduction/asyncAPI
# Out:
# asyncAPI.cu		 asyncAPI_vs2019.vcxproj  NsightEclipse.xml
# asyncAPI_vs2017.sln	 asyncAPI_vs2022.sln	  README.md
# asyncAPI_vs2017.vcxproj  asyncAPI_vs2022.vcxproj
# asyncAPI_vs2019.sln	 Makefile

# %%
# !make ./nvidia_cuda_samples/Samples/0_Introduction/asyncAPI
# Out:
# make: Nothing to be done for 'nvidia_cuda_samples/Samples/0_Introduction/asyncAPI'.
